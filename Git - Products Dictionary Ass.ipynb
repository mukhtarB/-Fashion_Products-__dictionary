# %%
products = {
    #------01------
    'Tops':{
        'shirts':{
            'Qty':20, 
            'price':500, 
            #'brand':['Old Navy', 'Diesel', 'Michael Kors'], 
            'color':['Red_s', 'Yellow_p', 'Green_p'], 
            'size':['M', 'L', 'XL']
        }, 
        'Polos':{
            'Qty':200, 
            'price':500, 
            #'brand':['Lacoste', 'Ralph Lauren', 'Calvin Klein'], 
            'color':['Blue', 'Orange', 'Red & White Strips'], 
            'size':['M', 'L', 'XXL']
        }, 
        'Vest':{
            'Qty':200, 
            'price':500, 
            #'brand':['Chase Deer', 'Tom Ford', 'Nike'], 
            'color':['White', 'Orange', 'Gray'], 
            'size':['S', 'M', 'L']
        }
        
    }, 
    #------02------
    'Pants':{
        'trousers':{
            'Qty':200, 
            'price':500, 
            #'brand':['Burberry', 'Loewe', 'Jacquemus'], 
            'color':['Black', 'White', 'Navy Blue'], 
            'size':['M', 'L', 'XL']
        }, 
        'Shorts':{
            'Qty':200, 
            'price':500, 
            #'brand':['Lacoste', 'Ralph Lauren', 'Burberry'], 
            'color':['Blue', 'Green', 'Gray'], 
            'size':['XS', 'S', 'M']
        }, 
        'Joggers':{
            'Qty':200, 
            'price':500, 
            #'brand':['Adidas', 'Nike', 'OFF-White'], 
            'color':['White', 'Black', 'Gray'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
    #------03------
    'UnderWear':{
        'Boxers':{
            'Qty':200, 
            'price':500, 
            #'brand':[], 
            'color':['White', 'Blue', 'Gray'], 
            'size':['M', 'L', 'XL']
        }, 
        'Briefs':{
            'Qty':200, 
            'price':500, 
            #'brand':['Lacoste', 'Tommy Hilfiger', 'Ralph Lauren'], 
            'color':['Red', 'Blue', 'Gray'], 
            'size':['M', 'L', 'XL']
        }, 
        'Boxer_briefs':{
            'Qty':200, 
            'price':500, 
            #'brand':['Hugo Boss', 'Tommy Hilfiger', 'Versace'], 
            'color':['White', 'Black', 'Gray'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
    #------04------
    'Suits':{
        '3 Piece':{
            'Qty':200, 
            'price':500, 
            #'brand':['Emporio Armani', 'Valentino', 'Dolce & Gabbana'], 
            'color':['BLue', 'Red', 'White', 'Gray', 'Black'], 
            'size':['M', 'L', 'XL']
        }, 
        'Double Brested':{
            'Qty':200, 
            'price':500, 
            #'brand':['Saint Lauren', 'Louis Vuitton', 'Gucci'], 
            'color':['BLue', 'Red', 'White', 'Gray', 'Black'], 
            'size':['M', 'L', 'XL']
        }, 
        'Blazers':{
            'Qty':200, 
            'price':500, 
            #'brand':['Hugo Boss', 'Emporio Armani', 'Hugo Boss'], 
            'color':['BLue', 'Red', 'White', 'Gray', 'Black'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
     #------05------
    'Watches':{
        'Leather':{
            'Qty':200, 
            'price':500, 
            #'brand':['Cartier', 'Michael Kors', 'Hublot'], 
            'color':['Black', 'White', 'Blue', 'Brown'], 
            'size':['M', 'L', 'XL']
        }, 
        'Chain':{
            'Qty':200, 
            'price':500, 
            #'brand':['Rolex', 'Casio', 'Adumeras Piguet'], 
            'color':['Blue', 'Orange', 'Red & White Strips'], 
            'size':['M', 'L', 'XL']
        }, 
        'Rubber':{
            'Qty':200, 
            'price':500, 
            #'brand':['G-Shock', 'Casio', 'Hublot'], 
            'color':['White', 'Black', 'Gray'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
     #------06-------
    'FootWear':{
        'Shoes':{
            'Qty':200, 
            'price':500, 
            #'brand':['Roberto Boticelli', 'Christian Dior', 'Gucci', 'Loubutin'], 
            'color':['White', 'Red', 'Black'], 
            'size':['M', 'L', 'XL']
        }, 
        'Sneakers':{
            'Qty':200, 
            'price':500, 
            #'brand':['Nike', 'Adidas', 'Under Armour'], 
            'color':['White', 'Red','Black'], 
            'size':['M', 'L', 'XL']
        }, 
        'Slides':{
            'Qty':200,
            'price':500, 
            #'brand':['Adidas', 'Nike'], 
            'color':['Red', 'Blue',  'White',  'Black',  'Gray'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
     #------07------ #head warmers, hats, buckethats, facecaps, headbands
    'HeadGear':{
        'Caps':{
            'Qty':200, 
            'price':500, 
            #'brand':['Nike', 'Adidas', 'NBA'], 
            'color':['Red', 'Nike', 'Adidas'], 
            'size':['M', 'L', 'XL']
        }, 
        'Hats':{
            'Qty':200, 
            'price':500, 
            #'brand':['Nike', 'Ralph Lauren', 'Jordans'], 
            'color':['Blue', 'Orange', 'Red & White Strips'], 
            'size':['M', 'L', 'XL']
        }, 
        'Headbands':{
            'Qty':200, 
            'price':500, 
            #'brand':['New Balance', 'Jordans'], 
            'color':['White', 'Black', 'Gray'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
     #------08-------
    'Shades':{
        'Round':{
            'Qty':200, 
            'price':500, 
            #'brand':['Cartier', 'Diesel', 'Ray Ban'], 
            'color':['Black', 'White', 'Maroon'], 
            'size':['M', 'L', 'XL']
        }, 
        'Square':{
            'Qty':200, 
            'price':500, 
            #'brand':['Lacoste', 'Ralph Lauren'], 
            'color':['Black', 'White', 'Maroon'], 
            'size':['M', 'L', 'XL']
        }, 
        'Others':{
            'Qty':200, 
            'price':500, 
            #'brand':['Chase Deer', 'Lux'], 
            'color':['Black', 'White', 'Maroon'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
     #------09------
    'Belts':{
        'Buckle':{
            'Qty':200, 
            'price':500, 
            #'brand':['Louis Vuitton', 'Dolce & Gabbana', 'Hugo Boss'], 
            'color':['Black', 'White', 'Brown'], 
            'size':['M', 'L', 'XL']
        }, 
        'Military':{
            'Qty':200, 
            'price':500, 
            #'brand':['N/A'], 
            'color':['N/A'], 
            'size':['M', 'L', 'XL']
        }, 
        'Suspenders':{
            'Qty':200, 
            'price':500, 
            #'brand':['Trafalgers', 'Albert Thurston', 'Turnbull & Asser'], 
            'color':['White', 'Black', 'Gray'], 
            'size':['M', 'L', 'XL']
        }
        
    }, 
     #-------10--------
    'Ornaments':{
        'Rings':{
            'Qty':200, 
            'price':500, 
            #'brand':['Versace', 'Chopard' 'Cartier', 'Harry Winston', 'Tiffany & Co.' ], 
            'color':['Gold', 'Silver', 'Black Diamonds', 'Rubby Diamonds'], 
            'size':['S', 'M', 'L', 'XL']
        }, 
        'Socks':{
            'Qty':200, 
            'price':500, 
            #'brand':['Puma', 'Adidas', 'Nike'], 
            'color':['White', 'Black', 'Gray'], 
            'size':['M', 'L', 'XL']
        }, 
        'Earings':{
            'Qty':200, 
            'price':500, 
            #'brand':['Gucci', 'Tom Wood', 'Balenciaga'], 
            'color':['White', 'Black', 'Gray'], 
            'size':['S', 'M', 'L']
        }
        
    }
    
  
    
    
}

# %%
for k in products:
    for x in products[k]:
        print('\n\r', x.upper(), ': \n\r')
        for y in products[k][x]:
            print(y, ' : ', products[k][x][y])
# Out:
#  SHIRTS :
#
# Qty  :  20
# price  :  500
# color  :  ['Red_s', 'Yellow_p', 'Green_p']
# size  :  ['M', 'L', 'XL']
#
#  POLOS :
#
# Qty  :  200
# price  :  500
# color  :  ['Blue', 'Orange', 'Red & White Strips']
# size  :  ['M', 'L', 'XXL']
#
#  VEST :
#
# Qty  :  200
# price  :  500
# color  :  ['White', 'Orange', 'Gray']
# size  :  ['S', 'M', 'L']
#
#  TROUSERS :
#
# Qty  :  200
# price  :  500
# color  :  ['Black', 'White', 'Navy Blue']
# size  :  ['M', 'L', 'XL']
#
#  SHORTS :
#
# Qty  :  200
# price  :  500
# color  :  ['Blue', 'Green', 'Gray']
# size  :  ['XS', 'S', 'M']
#
#  JOGGERS :
#
# Qty  :  200
# price  :  500
# color  :  ['White', 'Black', 'Gray']
# size  :  ['M', 'L', 'XL']
#
#  BOXERS :
#
# Qty  :  200
# price  :  500
# color  :  ['White', 'Blue', 'Gray']
# size  :  ['M', 'L', 'XL']
#
#  BRIEFS :
#
# Qty  :  200
# price  :  500
# color  :  ['Red', 'Blue', 'Gray']
# size  :  ['M', 'L', 'XL']
#
#  BOXER_BRIEFS :
#
# Qty  :  200
# price  :  500
# ...

# %%
for k in products:
    for x in products[k]:
        print(x.upper(), end = " : ")
        print(products[k][x], '\n\r')
# Out:
# SHIRTS : {'Qty': 20, 'price': 500, 'color': ['Red_s', 'Yellow_p', 'Green_p'], 'size': ['M', 'L', 'XL']}
#
# POLOS : {'Qty': 200, 'price': 500, 'color': ['Blue', 'Orange', 'Red & White Strips'], 'size': ['M', 'L', 'XXL']}
#
# VEST : {'Qty': 200, 'price': 500, 'color': ['White', 'Orange', 'Gray'], 'size': ['S', 'M', 'L']}
#
# TROUSERS : {'Qty': 200, 'price': 500, 'color': ['Black', 'White', 'Navy Blue'], 'size': ['M', 'L', 'XL']}
#
# SHORTS : {'Qty': 200, 'price': 500, 'color': ['Blue', 'Green', 'Gray'], 'size': ['XS', 'S', 'M']}
#
# JOGGERS : {'Qty': 200, 'price': 500, 'color': ['White', 'Black', 'Gray'], 'size': ['M', 'L', 'XL']}
#
# BOXERS : {'Qty': 200, 'price': 500, 'color': ['White', 'Blue', 'Gray'], 'size': ['M', 'L', 'XL']}
#
# BRIEFS : {'Qty': 200, 'price': 500, 'color': ['Red', 'Blue', 'Gray'], 'size': ['M', 'L', 'XL']}
#
# BOXER_BRIEFS : {'Qty': 200, 'price': 500, 'color': ['White', 'Black', 'Gray'], 'size': ['M', 'L', 'XL']}
#
# ...
